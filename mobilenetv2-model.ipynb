# %%
import os
import platform
from IPython.display import clear_output
print(platform.platform())

def resolve_dir(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)

def reset_path(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)
    else:
        os.system('rm -f {}/*'.format( Dir))
# Out:
# Windows-10-10.0.22621-SP0

# %%
import tensorflow as tf 
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) == 0:
    print("No GPU devices found.")
else:
    print("Available GPU devices:")
    for device in physical_devices:
        print(device)
# Out:
# WARNING:tensorflow:From d:\Projects\RL\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# No GPU devices found.

# %%
import tensorflow as tf
tf.random.set_seed(73)
TPU_INIT = False

if TPU_INIT:
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
        tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
    
    except ValueError:
        raise BaseException('ERROR: Not connected to a TPU runtime!')
# else:
#     !nvidia-smi;    

print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.15.0

# %%
MyDrive = '/kaggle/working'

PROJECT_DIR = '../input/real-life-violence-situations-dataset'
# !ls {PROJECT_DIR}

# %% [markdown]
# ## **Preprocessing**
# + **Getting frames form video**
# + **some image argumentations**

# %%
import cv2
import os
import imageio
import imgaug.augmenters as iaa
import imgaug as ia

IMG_SIZE = 128
ColorChannels = 3

def video_to_frames(video):
    vidcap = cv2.VideoCapture(video)
    
    import math
    rate = math.floor(vidcap.get(3))
    count = 0
    
    ImageFrames = []
    while vidcap.isOpened():
        ID = vidcap.get(1)
        success, image = vidcap.read()
        
        if success:
            # skipping frames to avoid duplications 
            if (ID % 7 == 0):
                flip = iaa.Fliplr(1.0)
                zoom = iaa.Affine(scale=1.3)
                random_brightness = iaa.Multiply((1, 1.3))
                rotate = iaa.Affine(rotate=(-25, 25))
                
                image_aug = flip(image = image)
                image_aug = random_brightness(image = image_aug)
                image_aug = zoom(image = image_aug)
                image_aug = rotate(image = image_aug)
                
                rgb_img = cv2.cvtColor(image_aug, cv2.COLOR_BGR2RGB)
                resized = cv2.resize(rgb_img, (IMG_SIZE, IMG_SIZE))
                ImageFrames.append(resized)
                
            count += 1
        else:
            break
    
    vidcap.release()
    
    return ImageFrames

# %%
# %%time
from tqdm import tqdm

# VideoDataDir = PROJECT_DIR + '/video'
VideoDataDir = './video'
print('we have \n{} Violence videos \n{} NonViolence videos'.format(
              len(os.listdir(VideoDataDir + '/Violence')), 
              len(os.listdir(VideoDataDir + '/NonViolence'))))

X_original = []
y_original = []

print('i choose 700 videos out of 2000, cuz of memory issue')
CLASSES = ["NonViolence", "Violence"]
#700 <- 350 + 350

for category in os.listdir(VideoDataDir):
    path = os.path.join(VideoDataDir, category)
    class_num = CLASSES.index(category)
    for i, video in enumerate(tqdm(os.listdir(path)[0:350])):
        frames = video_to_frames(path + '/' + video)
        for j, frame in enumerate(frames):
            X_original.append(frame)
            y_original.append(class_num)
# Out:
# we have
# 1000 Violence videos
# 1000 NonViolence videos
# i choose 700 videos out of 2000, cuz of memory issue
# 100%|██████████| 350/350 [01:59<00:00,  2.92it/s]
# 100%|██████████| 350/350 [03:04<00:00,  1.90it/s]
# CPU times: total: 4min 16s
# Wall time: 5min 4s

# %%
import numpy as np
X_original = np.array(X_original).reshape(-1 , IMG_SIZE * IMG_SIZE * 3)
y_original = np.array(y_original)
len(X_original)
# Out:
# 13979

# %%
from sklearn.model_selection import StratifiedShuffleSplit

stratified_sample = StratifiedShuffleSplit(n_splits=2, test_size=0.3, random_state=73)

for train_index, test_index in stratified_sample.split(X_original, y_original):
    X_train, X_test = X_original[train_index], X_original[test_index]
    y_train, y_test = y_original[train_index], y_original[test_index]

X_train_nn = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255
X_test_nn = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255

# %% [markdown]
# ## **Model Training**

# %%
# %pip install imutils
clear_output()

# %%
import cv2
import os
import numpy as np
import pickle
import matplotlib
matplotlib.use("Agg")

from keras.layers import Input
from keras.layers import Dropout, Flatten, Dense
from keras.models import Model

import matplotlib.pyplot as plt

# %%
epochs = 150

from keras import regularizers
kernel_regularizer = regularizers.l2(0.0001)

from keras.applications import MobileNetV2

def load_layers():
    input_tensor = Input(shape=(IMG_SIZE, IMG_SIZE, ColorChannels))
    baseModel = MobileNetV2(pooling='avg',
                            include_top=False, 
                            input_tensor=input_tensor)
    
    headModel = baseModel.output   
    headModel = Dense(1, activation="sigmoid")(headModel)
    model = Model(inputs=baseModel.input, outputs=headModel)

    for layer in baseModel.layers:
        layer.trainable = False

    print("Compiling model...")
    model.compile(loss="binary_crossentropy",
                    optimizer='adam',
                    metrics=["accuracy"])

    return model

if TPU_INIT:
    with tpu_strategy.scope():
        model = load_layers()
else:
    model = load_layers()

model.summary()
# Out:
# WARNING:tensorflow:From d:\Projects\RL\.venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:From d:\Projects\RL\.venv\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Compiling model...
# WARNING:tensorflow:From d:\Projects\RL\.venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 64, 64, 32)           864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 64, 64, 32)           128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 64, 64, 32)           0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 64, 64, 32)           288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 64, 64, 32)           128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 64, 64, 32)           0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 64, 64, 16)           512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 64, 64, 16)           64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 64, 64, 96)           1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 64, 64, 96)           384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 64, 64, 96)           0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 65, 65, 96)           0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 32, 32, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 32, 32, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 32, 32, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 32, 32, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 32, 32, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 32, 32, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 32, 32, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 32, 32, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 32, 32, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 33, 33, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 16, 16, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 16, 16, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 16, 16, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 16, 16, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 16, 16, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 16, 16, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 17, 17, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 8, 8, 192)            1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 8, 8, 192)            768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 8, 8, 192)            0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 8, 8, 64)             12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 8, 8, 64)             0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 8, 8, 64)             0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 8, 8, 64)             0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 8, 8, 384)            24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 8, 8, 384)            1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 8, 8, 384)            0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 8, 8, 384)            3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 8, 8, 384)            1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 8, 8, 384)            0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 8, 8, 96)             36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 8, 8, 96)             384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 8, 8, 96)             384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 8, 8, 96)             0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 8, 8, 96)             384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 8, 8, 96)             0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 9, 9, 576)            0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 4, 4, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 4, 4, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 4, 4, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 4, 4, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 4, 4, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 4, 4, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 4, 4, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 4, 4, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 4, 4, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 4, 4, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 4, 4, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 4, 4, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 4, 4, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 4, 4, 1280)           0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1280)                 0         ['out_relu[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                    1281      ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 2259265 (8.62 MB)
# Trainable params: 1281 (5.00 KB)
# Non-trainable params: 2257984 (8.61 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau

patience = 3

start_lr = 0.00001
min_lr = 0.00001
max_lr = 0.00005

batch_size = 4

if TPU_INIT:
    max_lr = max_lr * tpu_strategy.num_replicas_in_sync
    batch_size = batch_size * tpu_strategy.num_replicas_in_sync

rampup_epochs = 5
sustain_epochs = 0
exp_decay = .8

def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr


class myCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if ((logs.get('accuracy')>=0.999)):
            print("\nLimits Reached cancelling training!")
            self.model.stop_training = True

# %%
end_callback = myCallback()

lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=False)

early_stopping = EarlyStopping(patience = patience, monitor='val_loss',
                                 mode='min', restore_best_weights=True, 
                                 verbose = 1, min_delta = .00075)

PROJECT_DIR = MyDrive + '/RiskDetection'

lr_plat = ReduceLROnPlateau(patience = 2, mode = 'min')

os.system('rm -rf ./logs/')

import datetime
log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir = log_dir, write_graph=True, histogram_freq=1)

checkpoint_filepath = 'model/ModelWeights.h5'

model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                        save_weights_only=True,
                                        monitor='val_loss',
                                        mode='min',
                                        verbose = 1,
                                        save_best_only=True)


callbacks = [end_callback, lr_callback, model_checkpoints, tensorboard_callback, early_stopping, lr_plat]

if TPU_INIT:
    callbacks = [end_callback, lr_callback, model_checkpoints, early_stopping, lr_plat]

# %%
print('Training head...')

history = model.fit(X_train_nn ,y_train, epochs=epochs,
                        callbacks=callbacks,
                        validation_data = (X_test_nn, y_test),
                        batch_size=batch_size)

print('\nRestoring best Weights for MobileNetV2')
model.load_weights(checkpoint_filepath)
args_model = 'model/model.h5'
model.save(args_model)
# Out:
# Training head...
# Epoch 1/150
# WARNING:tensorflow:From d:\Projects\RL\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From d:\Projects\RL\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 2447/2447 [==============================] - ETA: 0s - loss: 0.7676 - accuracy: 0.5716
# Epoch 1: val_loss improved from inf to 0.63723, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 144s 55ms/step - loss: 0.7676 - accuracy: 0.5716 - val_loss: 0.6372 - val_accuracy: 0.6564 - lr: 1.0000e-05
# Epoch 2/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.5346 - accuracy: 0.7335
# Epoch 2: val_loss improved from 0.63723 to 0.45420, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 122s 50ms/step - loss: 0.5346 - accuracy: 0.7336 - val_loss: 0.4542 - val_accuracy: 0.7935 - lr: 1.8000e-05
# Epoch 3/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.3968 - accuracy: 0.8273
# Epoch 3: val_loss improved from 0.45420 to 0.35475, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 120s 49ms/step - loss: 0.3968 - accuracy: 0.8273 - val_loss: 0.3547 - val_accuracy: 0.8507 - lr: 2.6000e-05
# Epoch 4/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.3175 - accuracy: 0.8740
# Epoch 4: val_loss improved from 0.35475 to 0.29708, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 120s 49ms/step - loss: 0.3177 - accuracy: 0.8739 - val_loss: 0.2971 - val_accuracy: 0.8836 - lr: 3.4000e-05
# Epoch 5/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.2678 - accuracy: 0.8968
# Epoch 5: val_loss improved from 0.29708 to 0.25907, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 121s 49ms/step - loss: 0.2678 - accuracy: 0.8968 - val_loss: 0.2591 - val_accuracy: 0.8958 - lr: 4.2000e-05
# Epoch 6/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.2339 - accuracy: 0.9099
# Epoch 6: val_loss improved from 0.25907 to 0.23490, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 118s 48ms/step - loss: 0.2339 - accuracy: 0.9099 - val_loss: 0.2349 - val_accuracy: 0.9089 - lr: 5.0000e-05
# Epoch 7/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.2114 - accuracy: 0.9197
# Epoch 7: val_loss improved from 0.23490 to 0.21948, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 118s 48ms/step - loss: 0.2114 - accuracy: 0.9197 - val_loss: 0.2195 - val_accuracy: 0.9127 - lr: 4.2000e-05
# Epoch 8/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1973 - accuracy: 0.9256
# Epoch 8: val_loss improved from 0.21948 to 0.21100, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 120s 49ms/step - loss: 0.1973 - accuracy: 0.9255 - val_loss: 0.2110 - val_accuracy: 0.9177 - lr: 3.5600e-05
# Epoch 9/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1875 - accuracy: 0.9311
# Epoch 9: val_loss improved from 0.21100 to 0.20389, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 120s 49ms/step - loss: 0.1875 - accuracy: 0.9311 - val_loss: 0.2039 - val_accuracy: 0.9242 - lr: 3.0480e-05
# Epoch 10/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1805 - accuracy: 0.9345
# Epoch 10: val_loss improved from 0.20389 to 0.19893, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 117s 48ms/step - loss: 0.1805 - accuracy: 0.9345 - val_loss: 0.1989 - val_accuracy: 0.9247 - lr: 2.6384e-05
# Epoch 11/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1750 - accuracy: 0.9368
# Epoch 11: val_loss improved from 0.19893 to 0.19518, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 117s 48ms/step - loss: 0.1750 - accuracy: 0.9368 - val_loss: 0.1952 - val_accuracy: 0.9258 - lr: 2.3107e-05
# Epoch 12/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1703 - accuracy: 0.9388
# Epoch 12: val_loss improved from 0.19518 to 0.19235, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 117s 48ms/step - loss: 0.1703 - accuracy: 0.9388 - val_loss: 0.1924 - val_accuracy: 0.9275 - lr: 2.0486e-05
# Epoch 13/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1668 - accuracy: 0.9400
# Epoch 13: val_loss improved from 0.19235 to 0.18947, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 116s 48ms/step - loss: 0.1668 - accuracy: 0.9400 - val_loss: 0.1895 - val_accuracy: 0.9278 - lr: 1.8389e-05
# Epoch 14/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1637 - accuracy: 0.9417
# Epoch 14: val_loss improved from 0.18947 to 0.18733, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 118s 48ms/step - loss: 0.1637 - accuracy: 0.9417 - val_loss: 0.1873 - val_accuracy: 0.9294 - lr: 1.6711e-05
# Epoch 15/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1609 - accuracy: 0.9440
# Epoch 15: val_loss improved from 0.18733 to 0.18552, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 136s 55ms/step - loss: 0.1609 - accuracy: 0.9440 - val_loss: 0.1855 - val_accuracy: 0.9306 - lr: 1.5369e-05
# Epoch 16/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1586 - accuracy: 0.9442
# Epoch 16: val_loss improved from 0.18552 to 0.18371, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 145s 59ms/step - loss: 0.1586 - accuracy: 0.9442 - val_loss: 0.1837 - val_accuracy: 0.9304 - lr: 1.4295e-05
# Epoch 17/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1563 - accuracy: 0.9444
# Epoch 17: val_loss improved from 0.18371 to 0.18249, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 144s 59ms/step - loss: 0.1566 - accuracy: 0.9443 - val_loss: 0.1825 - val_accuracy: 0.9330 - lr: 1.3436e-05
# Epoch 18/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1548 - accuracy: 0.9460
# Epoch 18: val_loss improved from 0.18249 to 0.18090, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 147s 60ms/step - loss: 0.1547 - accuracy: 0.9460 - val_loss: 0.1809 - val_accuracy: 0.9330 - lr: 1.2749e-05
# Epoch 19/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1532 - accuracy: 0.9462
# Epoch 19: val_loss improved from 0.18090 to 0.17964, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 145s 59ms/step - loss: 0.1531 - accuracy: 0.9462 - val_loss: 0.1796 - val_accuracy: 0.9337 - lr: 1.2199e-05
# Epoch 20/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1516 - accuracy: 0.9469
# Epoch 20: val_loss improved from 0.17964 to 0.17850, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 144s 59ms/step - loss: 0.1516 - accuracy: 0.9469 - val_loss: 0.1785 - val_accuracy: 0.9342 - lr: 1.1759e-05
# Epoch 21/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1501 - accuracy: 0.9478
# Epoch 21: val_loss improved from 0.17850 to 0.17741, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 145s 59ms/step - loss: 0.1501 - accuracy: 0.9478 - val_loss: 0.1774 - val_accuracy: 0.9344 - lr: 1.1407e-05
# Epoch 22/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1487 - accuracy: 0.9478
# Epoch 22: val_loss improved from 0.17741 to 0.17643, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 148s 60ms/step - loss: 0.1487 - accuracy: 0.9478 - val_loss: 0.1764 - val_accuracy: 0.9347 - lr: 1.1126e-05
# Epoch 23/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1474 - accuracy: 0.9490
# Epoch 23: val_loss improved from 0.17643 to 0.17546, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 149s 61ms/step - loss: 0.1474 - accuracy: 0.9490 - val_loss: 0.1755 - val_accuracy: 0.9354 - lr: 1.0901e-05
# Epoch 24/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1462 - accuracy: 0.9497
# Epoch 24: val_loss improved from 0.17546 to 0.17478, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 146s 60ms/step - loss: 0.1462 - accuracy: 0.9497 - val_loss: 0.1748 - val_accuracy: 0.9363 - lr: 1.0721e-05
# Epoch 25/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1450 - accuracy: 0.9489
# Epoch 25: val_loss improved from 0.17478 to 0.17387, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 144s 59ms/step - loss: 0.1450 - accuracy: 0.9489 - val_loss: 0.1739 - val_accuracy: 0.9363 - lr: 1.0576e-05
# Epoch 26/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9508
# Epoch 26: val_loss improved from 0.17387 to 0.17287, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 143s 58ms/step - loss: 0.1439 - accuracy: 0.9508 - val_loss: 0.1729 - val_accuracy: 0.9368 - lr: 1.0461e-05
# Epoch 27/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1428 - accuracy: 0.9507
# Epoch 27: val_loss improved from 0.17287 to 0.17201, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 141s 57ms/step - loss: 0.1428 - accuracy: 0.9507 - val_loss: 0.1720 - val_accuracy: 0.9368 - lr: 1.0369e-05
# Epoch 28/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9508
# Epoch 28: val_loss improved from 0.17201 to 0.17148, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 143s 58ms/step - loss: 0.1416 - accuracy: 0.9508 - val_loss: 0.1715 - val_accuracy: 0.9368 - lr: 1.0295e-05
# Epoch 29/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9514
# Epoch 29: val_loss improved from 0.17148 to 0.17051, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 141s 58ms/step - loss: 0.1407 - accuracy: 0.9514 - val_loss: 0.1705 - val_accuracy: 0.9378 - lr: 1.0236e-05
# Epoch 30/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1398 - accuracy: 0.9519
# Epoch 30: val_loss improved from 0.17051 to 0.16981, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 142s 58ms/step - loss: 0.1398 - accuracy: 0.9519 - val_loss: 0.1698 - val_accuracy: 0.9382 - lr: 1.0189e-05
# Epoch 31/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9524
# Epoch 31: val_loss improved from 0.16981 to 0.16905, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 140s 57ms/step - loss: 0.1388 - accuracy: 0.9524 - val_loss: 0.1691 - val_accuracy: 0.9366 - lr: 1.0151e-05
# Epoch 32/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9532
# Epoch 32: val_loss improved from 0.16905 to 0.16827, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 141s 57ms/step - loss: 0.1378 - accuracy: 0.9532 - val_loss: 0.1683 - val_accuracy: 0.9382 - lr: 1.0121e-05
# Epoch 33/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1369 - accuracy: 0.9537
# Epoch 33: val_loss improved from 0.16827 to 0.16759, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 141s 58ms/step - loss: 0.1369 - accuracy: 0.9537 - val_loss: 0.1676 - val_accuracy: 0.9375 - lr: 1.0097e-05
# Epoch 34/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1360 - accuracy: 0.9534
# Epoch 34: val_loss improved from 0.16759 to 0.16699, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 140s 57ms/step - loss: 0.1360 - accuracy: 0.9534 - val_loss: 0.1670 - val_accuracy: 0.9390 - lr: 1.0077e-05
# Epoch 35/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9543
# Epoch 35: val_loss improved from 0.16699 to 0.16630, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 142s 58ms/step - loss: 0.1351 - accuracy: 0.9543 - val_loss: 0.1663 - val_accuracy: 0.9382 - lr: 1.0062e-05
# Epoch 36/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9549
# Epoch 36: val_loss improved from 0.16630 to 0.16569, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 140s 57ms/step - loss: 0.1343 - accuracy: 0.9549 - val_loss: 0.1657 - val_accuracy: 0.9392 - lr: 1.0050e-05
# Epoch 37/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1333 - accuracy: 0.9559
# Epoch 37: val_loss improved from 0.16569 to 0.16552, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 140s 57ms/step - loss: 0.1333 - accuracy: 0.9559 - val_loss: 0.1655 - val_accuracy: 0.9375 - lr: 1.0040e-05
# Epoch 38/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9553
# Epoch 38: val_loss improved from 0.16552 to 0.16442, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 141s 58ms/step - loss: 0.1327 - accuracy: 0.9553 - val_loss: 0.1644 - val_accuracy: 0.9390 - lr: 1.0032e-05
# Epoch 39/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1318 - accuracy: 0.9562
# Epoch 39: val_loss improved from 0.16442 to 0.16421, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 140s 57ms/step - loss: 0.1318 - accuracy: 0.9562 - val_loss: 0.1642 - val_accuracy: 0.9409 - lr: 1.0025e-05
# Epoch 40/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1310 - accuracy: 0.9570
# Epoch 40: val_loss improved from 0.16421 to 0.16343, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 141s 58ms/step - loss: 0.1310 - accuracy: 0.9570 - val_loss: 0.1634 - val_accuracy: 0.9413 - lr: 1.0020e-05
# Epoch 41/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.9567
# Epoch 41: val_loss improved from 0.16343 to 0.16269, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 139s 57ms/step - loss: 0.1303 - accuracy: 0.9567 - val_loss: 0.1627 - val_accuracy: 0.9392 - lr: 1.0016e-05
# Epoch 42/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1296 - accuracy: 0.9575
# Epoch 42: val_loss improved from 0.16269 to 0.16215, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 139s 57ms/step - loss: 0.1296 - accuracy: 0.9575 - val_loss: 0.1622 - val_accuracy: 0.9402 - lr: 1.0013e-05
# Epoch 43/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1286 - accuracy: 0.9579
# Epoch 43: val_loss did not improve from 0.16215
# 2447/2447 [==============================] - 138s 56ms/step - loss: 0.1286 - accuracy: 0.9579 - val_loss: 0.1625 - val_accuracy: 0.9416 - lr: 1.0010e-05
# Epoch 44/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1281 - accuracy: 0.9579
# Epoch 44: val_loss improved from 0.16215 to 0.16108, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 138s 57ms/step - loss: 0.1281 - accuracy: 0.9579 - val_loss: 0.1611 - val_accuracy: 0.9402 - lr: 1.0008e-05
# Epoch 45/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1273 - accuracy: 0.9578
# Epoch 45: val_loss improved from 0.16108 to 0.16057, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 138s 56ms/step - loss: 0.1273 - accuracy: 0.9578 - val_loss: 0.1606 - val_accuracy: 0.9399 - lr: 1.0007e-05
# Epoch 46/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 0.9582
# Epoch 46: val_loss improved from 0.16057 to 0.16009, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 139s 57ms/step - loss: 0.1266 - accuracy: 0.9582 - val_loss: 0.1601 - val_accuracy: 0.9394 - lr: 1.0005e-05
# Epoch 47/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1259 - accuracy: 0.9584
# Epoch 47: val_loss improved from 0.16009 to 0.15956, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 143s 58ms/step - loss: 0.1259 - accuracy: 0.9584 - val_loss: 0.1596 - val_accuracy: 0.9411 - lr: 1.0004e-05
# Epoch 48/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1253 - accuracy: 0.9586
# Epoch 48: val_loss improved from 0.15956 to 0.15910, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 141s 58ms/step - loss: 0.1253 - accuracy: 0.9586 - val_loss: 0.1591 - val_accuracy: 0.9402 - lr: 1.0003e-05
# Epoch 49/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1247 - accuracy: 0.9596
# Epoch 49: val_loss improved from 0.15910 to 0.15873, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 140s 57ms/step - loss: 0.1246 - accuracy: 0.9596 - val_loss: 0.1587 - val_accuracy: 0.9430 - lr: 1.0003e-05
# Epoch 50/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.9591
# Epoch 50: val_loss improved from 0.15873 to 0.15814, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 142s 58ms/step - loss: 0.1240 - accuracy: 0.9591 - val_loss: 0.1581 - val_accuracy: 0.9423 - lr: 1.0002e-05
# Epoch 51/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9596
# Epoch 51: val_loss improved from 0.15814 to 0.15772, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 141s 58ms/step - loss: 0.1234 - accuracy: 0.9596 - val_loss: 0.1577 - val_accuracy: 0.9425 - lr: 1.0002e-05
# Epoch 52/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1227 - accuracy: 0.9592
# Epoch 52: val_loss improved from 0.15772 to 0.15722, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 142s 58ms/step - loss: 0.1227 - accuracy: 0.9592 - val_loss: 0.1572 - val_accuracy: 0.9416 - lr: 1.0001e-05
# Epoch 53/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1220 - accuracy: 0.9600
# Epoch 53: val_loss improved from 0.15722 to 0.15717, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 144s 59ms/step - loss: 0.1220 - accuracy: 0.9600 - val_loss: 0.1572 - val_accuracy: 0.9440 - lr: 1.0001e-05
# Epoch 54/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1215 - accuracy: 0.9594
# Epoch 54: val_loss improved from 0.15717 to 0.15633, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 143s 59ms/step - loss: 0.1215 - accuracy: 0.9594 - val_loss: 0.1563 - val_accuracy: 0.9428 - lr: 1.0001e-05
# Epoch 55/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1209 - accuracy: 0.9604
# Epoch 55: val_loss improved from 0.15633 to 0.15596, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 144s 59ms/step - loss: 0.1209 - accuracy: 0.9604 - val_loss: 0.1560 - val_accuracy: 0.9437 - lr: 1.0001e-05
# Epoch 56/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1203 - accuracy: 0.9609
# Epoch 56: val_loss improved from 0.15596 to 0.15563, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 143s 58ms/step - loss: 0.1203 - accuracy: 0.9609 - val_loss: 0.1556 - val_accuracy: 0.9437 - lr: 1.0001e-05
# Epoch 57/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9604
# Epoch 57: val_loss improved from 0.15563 to 0.15538, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 143s 58ms/step - loss: 0.1197 - accuracy: 0.9604 - val_loss: 0.1554 - val_accuracy: 0.9442 - lr: 1.0000e-05
# Epoch 58/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9616
# Epoch 58: val_loss improved from 0.15538 to 0.15468, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 142s 58ms/step - loss: 0.1192 - accuracy: 0.9616 - val_loss: 0.1547 - val_accuracy: 0.9430 - lr: 1.0000e-05
# Epoch 59/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1186 - accuracy: 0.9613
# Epoch 59: val_loss improved from 0.15468 to 0.15430, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 142s 58ms/step - loss: 0.1186 - accuracy: 0.9613 - val_loss: 0.1543 - val_accuracy: 0.9437 - lr: 1.0000e-05
# Epoch 60/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1180 - accuracy: 0.9615
# Epoch 60: val_loss improved from 0.15430 to 0.15392, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 142s 58ms/step - loss: 0.1180 - accuracy: 0.9615 - val_loss: 0.1539 - val_accuracy: 0.9437 - lr: 1.0000e-05
# Epoch 61/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1175 - accuracy: 0.9610
# Epoch 61: val_loss improved from 0.15392 to 0.15357, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 144s 59ms/step - loss: 0.1175 - accuracy: 0.9610 - val_loss: 0.1536 - val_accuracy: 0.9444 - lr: 1.0000e-05
# Epoch 62/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9610
# Epoch 62: val_loss improved from 0.15357 to 0.15316, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 126s 51ms/step - loss: 0.1169 - accuracy: 0.9610 - val_loss: 0.1532 - val_accuracy: 0.9433 - lr: 1.0000e-05
# Epoch 63/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.9620
# Epoch 63: val_loss improved from 0.15316 to 0.15281, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 122s 50ms/step - loss: 0.1164 - accuracy: 0.9620 - val_loss: 0.1528 - val_accuracy: 0.9442 - lr: 1.0000e-05
# Epoch 64/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1159 - accuracy: 0.9624
# Epoch 64: val_loss improved from 0.15281 to 0.15243, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 122s 50ms/step - loss: 0.1159 - accuracy: 0.9624 - val_loss: 0.1524 - val_accuracy: 0.9437 - lr: 1.0000e-05
# Epoch 65/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1154 - accuracy: 0.9631
# Epoch 65: val_loss improved from 0.15243 to 0.15217, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 120s 49ms/step - loss: 0.1154 - accuracy: 0.9631 - val_loss: 0.1522 - val_accuracy: 0.9447 - lr: 1.0000e-05
# Epoch 66/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1148 - accuracy: 0.9627
# Epoch 66: val_loss improved from 0.15217 to 0.15198, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 120s 49ms/step - loss: 0.1148 - accuracy: 0.9627 - val_loss: 0.1520 - val_accuracy: 0.9461 - lr: 1.0000e-05
# Epoch 67/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1143 - accuracy: 0.9630
# Epoch 67: val_loss improved from 0.15198 to 0.15150, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 120s 49ms/step - loss: 0.1143 - accuracy: 0.9630 - val_loss: 0.1515 - val_accuracy: 0.9449 - lr: 1.0000e-05
# Epoch 68/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1139 - accuracy: 0.9629
# Epoch 68: val_loss improved from 0.15150 to 0.15107, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 122s 50ms/step - loss: 0.1139 - accuracy: 0.9629 - val_loss: 0.1511 - val_accuracy: 0.9444 - lr: 1.0000e-05
# Epoch 69/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1134 - accuracy: 0.9630
# Epoch 69: val_loss improved from 0.15107 to 0.15073, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 119s 49ms/step - loss: 0.1134 - accuracy: 0.9630 - val_loss: 0.1507 - val_accuracy: 0.9442 - lr: 1.0000e-05
# Epoch 70/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1129 - accuracy: 0.9634
# Epoch 70: val_loss improved from 0.15073 to 0.15038, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 118s 48ms/step - loss: 0.1129 - accuracy: 0.9634 - val_loss: 0.1504 - val_accuracy: 0.9447 - lr: 1.0000e-05
# Epoch 71/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9636
# Epoch 71: val_loss improved from 0.15038 to 0.15010, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 118s 48ms/step - loss: 0.1124 - accuracy: 0.9636 - val_loss: 0.1501 - val_accuracy: 0.9444 - lr: 1.0000e-05
# Epoch 72/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9641
# Epoch 72: val_loss did not improve from 0.15010
# 2447/2447 [==============================] - 118s 48ms/step - loss: 0.1119 - accuracy: 0.9641 - val_loss: 0.1501 - val_accuracy: 0.9468 - lr: 1.0000e-05
# Epoch 73/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1115 - accuracy: 0.9637
# Epoch 73: val_loss improved from 0.15010 to 0.14944, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 118s 48ms/step - loss: 0.1115 - accuracy: 0.9637 - val_loss: 0.1494 - val_accuracy: 0.9449 - lr: 1.0000e-05
# Epoch 74/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9644
# Epoch 74: val_loss improved from 0.14944 to 0.14912, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 120s 49ms/step - loss: 0.1110 - accuracy: 0.9644 - val_loss: 0.1491 - val_accuracy: 0.9444 - lr: 1.0000e-05
# Epoch 75/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1106 - accuracy: 0.9645
# Epoch 75: val_loss improved from 0.14912 to 0.14884, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 119s 48ms/step - loss: 0.1106 - accuracy: 0.9645 - val_loss: 0.1488 - val_accuracy: 0.9456 - lr: 1.0000e-05
# Epoch 76/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.9646
# Epoch 76: val_loss improved from 0.14884 to 0.14854, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 120s 49ms/step - loss: 0.1101 - accuracy: 0.9646 - val_loss: 0.1485 - val_accuracy: 0.9456 - lr: 1.0000e-05
# Epoch 77/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.9653
# Epoch 77: val_loss improved from 0.14854 to 0.14826, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 118s 48ms/step - loss: 0.1096 - accuracy: 0.9653 - val_loss: 0.1483 - val_accuracy: 0.9456 - lr: 1.0000e-05
# Epoch 78/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1093 - accuracy: 0.9647
# Epoch 78: val_loss improved from 0.14826 to 0.14797, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 118s 48ms/step - loss: 0.1093 - accuracy: 0.9647 - val_loss: 0.1480 - val_accuracy: 0.9454 - lr: 1.0000e-05
# Epoch 79/150
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1088 - accuracy: 0.9647
# Epoch 79: val_loss improved from 0.14797 to 0.14775, saving model to model\ModelWeights.h5
# 2447/2447 [==============================] - 118s 48ms/step - loss: 0.1088 - accuracy: 0.9647 - val_loss: 0.1478 - val_accuracy: 0.9459 - lr: 1.0000e-05
# Epoch 80/150
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1084 - accuracy: 0.9652
# Epoch 80: val_loss improved from 0.14775 to 0.14773, saving model to model\ModelWeights.h5
# Restoring model weights from the end of the best epoch: 77.
# 2447/2447 [==============================] - 119s 48ms/step - loss: 0.1084 - accuracy: 0.9652 - val_loss: 0.1477 - val_accuracy: 0.9473 - lr: 1.0000e-05
# Epoch 80: early stopping
#
# Restoring best Weights for MobileNetV2
# d:\Projects\RL\.venv\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# %matplotlib inline

def print_graph(item, index, history):
    plt.figure()
    train_values = history.history[item][0:index]
    plt.plot(train_values)
    test_values = history.history['val_' + item][0:index]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    plt.show()
    plot = '{}.png'.format(item)
    plt.savefig(plot)


def get_best_epoch(test_loss, history):
    for key, item in enumerate(history.history.items()):
        (name, arr) = item
        if name == 'val_loss':
            for i in range(len(arr)):
                if round(test_loss, 2) == round(arr[i], 2):
                    return i
                
def model_summary(model, history):
    print('---'*30)
    test_loss, test_accuracy = model.evaluate(X_test_nn, y_test, verbose=0)

    if history:
        index = get_best_epoch(test_loss, history)
        print('Best Epochs: ', index)

        train_accuracy = history.history['accuracy'][index]
        train_loss = history.history['loss'][index]

        print('Accuracy on train:',train_accuracy,'\tLoss on train:',train_loss)
        print('Accuracy on test:',test_accuracy,'\tLoss on test:',test_loss)
        print_graph('loss', index, history)
        print_graph('accuracy', index, history)
        print('---'*30)

# %%
model_summary(model, history)
# Out:
# ------------------------------------------------------------------------------------------
# Best Epochs:  57
# Accuracy on train: 0.9615738391876221 	Loss on train: 0.11916068196296692
# Accuracy on test: 0.9473056793212891 	Loss on test: 0.14772655069828033
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## **Evaluation on test set**

# %%
# evaluate the network
print("Evaluating network...")
predictions = model.predict(X_test_nn)
preds = predictions > 0.5
# Out:
# Evaluating network...
# 132/132 [==============================] - 20s 143ms/step

# %%
import seaborn as sns
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score, classification_report, confusion_matrix
# from sklearn.metrics import plot_roc_curve
from sklearn.metrics import RocCurveDisplay

corr_pred = metrics.confusion_matrix(y_test, preds)

n_correct = int(corr_pred[0][0] + corr_pred[1][1])

print('> Correct Predictions:', n_correct)
n_wrongs = int(corr_pred[0][1] + corr_pred[1][0])

print('> Wrong Predictions:', n_wrongs)

sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Blues")
plt.show()

print(metrics.classification_report(y_test, preds, 
                           target_names=["NonViolence", "Violence"]))
# Out:
# > Correct Predictions: 3973
# > Wrong Predictions: 221
#               precision    recall  f1-score   support
#
#  NonViolence       0.95      0.92      0.94      1778
#     Violence       0.94      0.97      0.95      2416
#
#     accuracy                           0.95      4194
#    macro avg       0.95      0.94      0.95      4194
# weighted avg       0.95      0.95      0.95      4194

# %% [markdown]
# #### modal can learn better
# + **note: (only 35 % of data is used in this notebook), cuz of less ram memory**
